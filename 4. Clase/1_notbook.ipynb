# %% [markdown]
# Errores

# %%
print ("Hola")
# Out:
# Hola

# %%
try:
    number=1
    string="Hola"
    result=number+string
except:
    print("No se puede sumar un numero y una cadena")
# Out:
# No se puede sumar un numero y una cadena

# %%
try:
    number=1
    string="Hola"
    result=number+string
    var=string [10]
except TypeError as var2:
    print("Hay un error de tipo:", var2)
except IndexError as var2:
    print("Hay un error de indice:", var2)  
except Exception as var2:
    print("Ha ocurrido un error:", var2)
# Out:
# Hay un error de tipo: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    10/0
except ZeroDivisionError as var2:
    print("Error: Division por cero")
    raise ValueError("No se puede dividir por cero")
# Out:
# Error: Division por cero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 try:
# ----> 2     10/0
#       3 except ZeroDivisionError as var2:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 5
#       3 except ZeroDivisionError as var2:
#       4     print("Error: Division por cero")
# ----> 5     raise ValueError("No se puede dividir por cero")
#
# ValueError: No se puede dividir por cero

# %% [markdown]
# Control Condicionales

# %%
comp=1>0
comp2=0>0

if (comp):
    print("Cuando comp es TRUE")

if (comp):
    print("Cuando comp es TRUE")
else:
    print("Cuando comp es FALSE")

if (comp):
    print("Cuando comp es TRUE")
elif (comp and comp2):
    print("Otra condición pero negando la de arriba")
else: #Opcional
    print("Ninguna es TRUE")

if (comp):
    print("Cuando comp es TRUE")
    if (comp2):
        print("Cuando comp y comp2 es TRUE")
else:
    print("Cuando comp es FALSE")

if (comp and comp2):
    print("Cuando com y comp2 son TRUE")
# Out:
# Cuando comp es TRUE
# Cuando comp es TRUE
# Cuando comp es TRUE
# Cuando comp es TRUE

# %% [markdown]
# Funciones

# %%
def nmbre_funcion (a,b,c):
    return a+b, a+c, b+c, "Hola"

# %%
var=nmbre_funcion (1,2,3)
print (var) #el resultado es una tupla que sirve para almacenar vario s datos en una misma variable
# Out:
# (3, 4, 5, 'Hola')

# %%
# sacamos cada uno de los elementos de la tupla
print(var [0])
print(var [1])
print(var [2])
nmbre_funcion (var[0], var[1], var[2])
# Out:
# 3
# 4
# 5
# (7, 8, 9)

# %%
var[-1] #ultimo elemento de la tupla
var[-2] #penultimo elemento de la tupla
var[-3] #antepenultimo elemento de la tupla
var [-4] #cuarto elemento desde el final de la tupla
# Out:
# 3

# %%
tupla_variable=("hola",2,3,1.5,0xb)

# %%
tupla_variable[1:3]  #subtupla desde el indice 1 hasta el 2 (el 3 no se incluye)
# Out:
# (2, 3)

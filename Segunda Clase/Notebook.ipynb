# %% [markdown]
# # Variables en Python: (Se asignan y se usan)

# %% [markdown]
# ##Ejercicio

# %%
Var1=15
Var2=30

res_suma=Var1+Var2
res_resta=Var1-Var2
res_multiplicacion=Var1*Var2
res_division=Var1/Var2

print("Resultados")
print("Suma:", res_suma)
print("Resta:", res_resta)
print("Multiplicación:", res_multiplicacion)
print("División:", res_division)
# Out:
# Resultados
# Suma: 45
# Resta: -15
# Multiplicación: 450
# División: 0.5

# %%
2%13
# Out:
# 2

# %% [markdown]
# Lo que hace la operacion es el residuo de la división
